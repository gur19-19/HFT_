# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
BTC = yf.download('BTC-USD', start='2023-04-13', end='2023-04-14',  interval = '1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
BTC
# Out:
#                                    Open          High           Low  \
# Datetime
# 2023-04-13 00:00:00+00:00  29892.740234  29892.740234  29892.740234
# 2023-04-13 00:01:00+00:00  29905.982422  29905.982422  29905.982422
# 2023-04-13 00:02:00+00:00  29908.824219  29908.824219  29908.824219
# 2023-04-13 00:03:00+00:00  29910.234375  29910.234375  29910.234375
# 2023-04-13 00:04:00+00:00  29914.119141  29914.119141  29914.119141
# ...                                 ...           ...           ...
# 2023-04-13 23:54:00+00:00  30402.003906  30402.003906  30402.003906
# 2023-04-13 23:55:00+00:00  30391.673828  30391.673828  30391.673828
# 2023-04-13 23:56:00+00:00  30402.447266  30402.447266  30402.447266
# 2023-04-13 23:57:00+00:00  30414.632812  30414.632812  30414.632812
# 2023-04-13 23:58:00+00:00  30404.269531  30404.269531  30404.269531
#
#                                   Close     Adj Close    Volume
# Datetime
# 2023-04-13 00:00:00+00:00  29892.740234  29892.740234         0
# 2023-04-13 00:01:00+00:00  29905.982422  29905.982422         0
# 2023-04-13 00:02:00+00:00  29908.824219  29908.824219         0
# 2023-04-13 00:03:00+00:00  29910.234375  29910.234375   3131392
# 2023-04-13 00:04:00+00:00  29914.119141  29914.119141         0
# ...                                 ...           ...       ...
# 2023-04-13 23:54:00+00:00  30402.003906  30402.003906    993280
# 2023-04-13 23:55:00+00:00  30391.673828  30391.673828  14163968
# 2023-04-13 23:56:00+00:00  30402.447266  30402.447266   1988608
# 2023-04-13 23:57:00+00:00  30414.632812  30414.632812   2963456
# 2023-04-13 23:58:00+00:00  30404.269531  30404.269531         0
#
# [1412 rows x 6 columns]

# %%
ETH = yf.download('ETH-USD', start='2023-04-13', end='2023-04-14',  interval = '1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ETH
# Out:
#                                   Open         High          Low        Close  \
# Datetime
# 2023-04-13 00:00:00+00:00  1917.698364  1917.698364  1917.698364  1917.698364
# 2023-04-13 00:01:00+00:00  1918.471558  1918.471558  1918.471558  1918.471558
# 2023-04-13 00:02:00+00:00  1918.695679  1918.695679  1918.695679  1918.695679
# 2023-04-13 00:03:00+00:00  1919.426270  1919.426270  1919.426270  1919.426270
# 2023-04-13 00:04:00+00:00  1919.011475  1919.011475  1919.011475  1919.011475
# ...                                ...          ...          ...          ...
# 2023-04-13 23:54:00+00:00  2012.436768  2012.436768  2012.436768  2012.436768
# 2023-04-13 23:55:00+00:00  2011.610840  2011.610840  2011.610840  2011.610840
# 2023-04-13 23:56:00+00:00  2012.051392  2012.051392  2012.051392  2012.051392
# 2023-04-13 23:57:00+00:00  2013.478394  2013.478394  2013.478394  2013.478394
# 2023-04-13 23:58:00+00:00  2013.202637  2013.202637  2013.202637  2013.202637
#
#                              Adj Close   Volume
# Datetime
# 2023-04-13 00:00:00+00:00  1917.698364        0
# 2023-04-13 00:01:00+00:00  1918.471558        0
# 2023-04-13 00:02:00+00:00  1918.695679        0
# 2023-04-13 00:03:00+00:00  1919.426270  2255872
# 2023-04-13 00:04:00+00:00  1919.011475        0
# ...                                ...      ...
# 2023-04-13 23:54:00+00:00  2012.436768   358400
# 2023-04-13 23:55:00+00:00  2011.610840  1329152
# 2023-04-13 23:56:00+00:00  2012.051392  1024000
# 2023-04-13 23:57:00+00:00  2013.478394   627712
# 2023-04-13 23:58:00+00:00  2013.202637        0
#
# [1412 rows x 6 columns]

# %%
BTC.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   1412.000000   1412.000000   1412.000000   1412.000000   1412.000000
# mean   30234.928793  30234.928793  30234.928793  30234.928793  30234.928793
# std      147.201948    147.201948    147.201948    147.201948    147.201948
# min    29878.623047  29878.623047  29878.623047  29878.623047  29878.623047
# 25%    30098.723145  30098.723145  30098.723145  30098.723145  30098.723145
# 50%    30236.963867  30236.963867  30236.963867  30236.963867  30236.963867
# 75%    30354.698242  30354.698242  30354.698242  30354.698242  30354.698242
# max    30539.845703  30539.845703  30539.845703  30539.845703  30539.845703
#
#              Volume
# count  1.412000e+03
# mean   3.264097e+06
# std    9.122894e+06
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    2.634240e+06
# max    1.644052e+08

# %%
ETH.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1412.000000  1412.000000  1412.000000  1412.000000  1412.000000
# mean   1969.583118  1969.583118  1969.583118  1969.583118  1969.583118
# std      42.981875    42.981875    42.981875    42.981875    42.981875
# min    1901.860352  1901.860352  1901.860352  1901.860352  1901.860352
# 25%    1917.442474  1917.442474  1917.442474  1917.442474  1917.442474
# 50%    1991.480042  1991.480042  1991.480042  1991.480042  1991.480042
# 75%    2007.972168  2007.972168  2007.972168  2007.972168  2007.972168
# max    2022.150146  2022.150146  2022.150146  2022.150146  2022.150146
#
#              Volume
# count  1.412000e+03
# mean   3.472161e+06
# std    1.045471e+07
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    2.710016e+06
# max    1.459599e+08

# %%
lr1 = np.log(BTC['Adj Close'] / BTC['Adj Close'].shift(1))
lr2 = np.log(ETH['Adj Close'] / ETH['Adj Close'].shift(1))
mu_1 = lr1.mean() * 1440
mu_2 = lr2.mean() * 1440
sigma_1 = lr1.std() * np.sqrt(1440)
sigma_2 = lr2.std() * np.sqrt(1440)
rho = lr1.corr(lr2)
z_0 = 0.00
gamma = 0.5
delta = 0.8
T = 1
M = len(BTC)

# %%
mu_1
# Out:
# 0.017316121719224767

# %%
mu_2
# Out:
# 0.04959999611906963

# %%
sigma_1
# Out:
# 0.015488149951485647

# %%
sigma_2
# Out:
# 0.022469322375359674

# %%
result = linregress(np.log(BTC['Adj Close']), np.log(ETH['Adj Close']))
beta = result.slope

# %%
rho
# Out:
# 0.7452410127987951

# %%
beta
# Out:
# 4.026326296866955

# %%
BTC = yf.download('BTC-USD', start='2023-04-15', end='2023-04-16',  interval = '1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
BTC
# Out:
#                                    Open          High           Low  \
# Datetime
# 2023-04-15 00:00:00+00:00  30490.750000  30490.750000  30490.750000
# 2023-04-15 00:01:00+00:00  30491.595703  30491.595703  30491.595703
# 2023-04-15 00:02:00+00:00  30489.484375  30489.484375  30489.484375
# 2023-04-15 00:03:00+00:00  30480.996094  30480.996094  30480.996094
# 2023-04-15 00:04:00+00:00  30464.080078  30464.080078  30464.080078
# ...                                 ...           ...           ...
# 2023-04-15 23:54:00+00:00  30315.400391  30315.400391  30315.400391
# 2023-04-15 23:55:00+00:00  30323.533203  30323.533203  30323.533203
# 2023-04-15 23:56:00+00:00  30322.533203  30322.533203  30322.533203
# 2023-04-15 23:57:00+00:00  30323.902344  30323.902344  30323.902344
# 2023-04-15 23:58:00+00:00  30318.800781  30318.800781  30318.800781
#
#                                   Close     Adj Close  Volume
# Datetime
# 2023-04-15 00:00:00+00:00  30490.750000  30490.750000       0
# 2023-04-15 00:01:00+00:00  30491.595703  30491.595703       0
# 2023-04-15 00:02:00+00:00  30489.484375  30489.484375       0
# 2023-04-15 00:03:00+00:00  30480.996094  30480.996094       0
# 2023-04-15 00:04:00+00:00  30464.080078  30464.080078       0
# ...                                 ...           ...     ...
# 2023-04-15 23:54:00+00:00  30315.400391  30315.400391       0
# 2023-04-15 23:55:00+00:00  30323.533203  30323.533203       0
# 2023-04-15 23:56:00+00:00  30322.533203  30322.533203       0
# 2023-04-15 23:57:00+00:00  30323.902344  30323.902344       0
# 2023-04-15 23:58:00+00:00  30318.800781  30318.800781       0
#
# [1423 rows x 6 columns]

# %%
ETH = yf.download('ETH-USD', start='2023-04-15', end='2023-04-16',  interval = '1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ETH
# Out:
#                                   Open         High          Low        Close  \
# Datetime
# 2023-04-15 00:00:00+00:00  2101.616455  2101.616455  2101.616455  2101.616455
# 2023-04-15 00:01:00+00:00  2101.949463  2101.949463  2101.949463  2101.949463
# 2023-04-15 00:02:00+00:00  2101.617432  2101.617432  2101.617432  2101.617432
# 2023-04-15 00:03:00+00:00  2100.147461  2100.147461  2100.147461  2100.147461
# 2023-04-15 00:04:00+00:00  2096.116699  2096.116699  2096.116699  2096.116699
# ...                                ...          ...          ...          ...
# 2023-04-15 23:54:00+00:00  2092.785889  2092.785889  2092.785889  2092.785889
# 2023-04-15 23:55:00+00:00  2093.330811  2093.330811  2093.330811  2093.330811
# 2023-04-15 23:56:00+00:00  2093.046875  2093.046875  2093.046875  2093.046875
# 2023-04-15 23:57:00+00:00  2093.104492  2093.104492  2093.104492  2093.104492
# 2023-04-15 23:58:00+00:00  2092.590332  2092.590332  2092.590332  2092.590332
#
#                              Adj Close   Volume
# Datetime
# 2023-04-15 00:00:00+00:00  2101.616455        0
# 2023-04-15 00:01:00+00:00  2101.949463        0
# 2023-04-15 00:02:00+00:00  2101.617432   865280
# 2023-04-15 00:03:00+00:00  2100.147461        0
# 2023-04-15 00:04:00+00:00  2096.116699        0
# ...                                ...      ...
# 2023-04-15 23:54:00+00:00  2092.785889        0
# 2023-04-15 23:55:00+00:00  2093.330811        0
# 2023-04-15 23:56:00+00:00  2093.046875   641536
# 2023-04-15 23:57:00+00:00  2093.104492   136192
# 2023-04-15 23:58:00+00:00  2092.590332  5733376
#
# [1423 rows x 6 columns]

# %%
S1_0 = BTC['Open'][0]
S2_0 = ETH['Open'][0]

# %%
S1_0
# Out:
# 30490.75

# %%
S2_0
# Out:
# 2101.616455078125

# %%
dt = T/M
S1 = np.zeros((M + 1, 1))
S2 = np.zeros((M + 1, 1))
z =  np.zeros((M + 1, 1))
a =  np.zeros((M + 1, 1))
b =  np.zeros((M + 1, 1))
c =  np.zeros((M + 1, 1))
Pi_1 = np.zeros((M + 1, 1))
Pi_2 = np.zeros((M + 1, 1))

# %%
tt = np.linspace(0, 1, M + 1)
z[0] = z_0
S1[0] = S1_0
S2[0] = S2_0
sigma_beta = np.sqrt(sigma_1 ** 2 + beta ** 2 * sigma_2 ** 2 + 2 * beta * sigma_1 * sigma_2 * rho)
eta = (-1/delta) * (mu_1 - sigma_1 ** 2/2 + beta*(mu_2 - sigma_2 ** 2/2))
rn = np.random.standard_normal(z.shape)
rn1 = np.random.standard_normal(S1.shape) 
rn2 = np.random.standard_normal(S2.shape) 
for t in range(1, M + 1):
    z[t] = z[t-1]* (1 - delta * (eta - z[t-1])) * dt + sigma_beta * np.sqrt(dt)*((sigma_1 + beta * sigma_2 * rho)/ sigma_beta * rn1[t] + beta * (sigma_2 * np.sqrt(1-rho ** 2)/sigma_beta) * rn1[t]);
    S1[t] = S1[t-1] * np.exp((mu_1 + delta * z[t] - sigma_1 ** 2 / 2) * dt + sigma_1 * np.sqrt(dt) * rn1[t])
    S2[t] = S2[t-1] * np.exp((mu_2 - sigma_2 ** 2 / 2) * dt + sigma_2 * np.sqrt(dt) * (rho * rn1[t] + np.sqrt(1 - rho ** 2) * rn2[t]))

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, S1, 'b', lw=1.5, label='Stock 1')
plt.plot(tt, S2, 'r', lw=1.5, label='Stock 2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Stock Price')
# Out:
# Text(0.5, 1.0, 'Stock Price')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, z, 'g', lw=1.5)
plt.xlabel('Time')
plt.ylabel('Rate')
plt.title('z')
# Out:
# Text(0.5, 1.0, 'z')

# %%
for t in range(1, M + 1):
    a[t] = 0.5 * (T - t * dt)/((1-rho ** 2) * sigma_1 ** 2)
    b[t] = - 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2)/((1 - rho ** 2) * sigma_1 ** 2) - rho * mu_2 * (T - t * dt)/((1 - rho **2) * sigma_1 * sigma_2)
    c[t] = 0.5 * mu_2 ** 2 * (T - t * dt)/((1 - rho ** 2) * sigma_2 ** 2) + 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2 + 2 * sigma_1 * sigma_2 * beta *rho) * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2) + 0.25 * (T - t * dt) ** 2 * mu_2 * delta * rho * (sigma_1 ** 2 + beta * sigma_2 ** 2) + 1/24 * (T - t * dt) ** 3 * (sigma_1 ** 2 + beta * sigma_2 ** 2) ** 2 * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2)
    Pi_1[t] = (1 / S1[t]) * ((mu_1 + delta * z[t])/(gamma * (1 - rho ** 2) * sigma_1 ** 2) + delta/gamma * (-2 * a[t] * (mu_1 + delta * z[t])-b[t]) - rho * mu_2/(gamma * (1 - rho ** 2) * sigma_1 * sigma_2))
    Pi_2[t] = (1 / S2[t]) * (mu_2 / (gamma * (1 - rho ** 2) * sigma_2 ** 2) + delta * beta / gamma * (- 2 * a[t] * (mu_1 + delta * z[t]) - b[t]) - rho)

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1, 'b', lw=1.5, label='w1')
plt.plot(tt, Pi_2, 'r', lw=1.5, label='w2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('%')
plt.title('Weights')
# Out:
# Text(0.5, 1.0, 'Weights')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1, 'b', lw=1.5, label='Wealth 1')
plt.plot(tt, Pi_2 * S2, 'r', lw=1.5, label='Wealth 2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Wealth')
# Out:
# Text(0.5, 1.0, 'Wealth')

# %%
Wealth = abs(Pi_1 * S1) + abs(Pi_2 * S2)

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt[1:], Wealth[1:], 'b', lw=1.5, label='Total')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Wealth')
# Out:
# Text(0.5, 1.0, 'Wealth')

# %%
Wealth[1]
# Out:
# array([1253.82752657])

# %%
Wealth[-1]
# Out:
# array([555.56110219])

# %%
Return = (Wealth[-1] - Wealth[1])/Wealth[1]  # Return
Return.item()
# Out:
# -0.5569078757502648

# %%
rho
# Out:
# 0.7452410127987951

# %%
beta
# Out:
# 4.026326296866955

# %%
Pi_1.mean()
# Out:
# -0.002860902383305469

# %%
Pi_2.mean()
# Out:
# 0.3301727195443195

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1 + Pi_2 * S2, 'b', lw=1.5, label='Dynamic')
plt.plot(tt, Pi_1.mean() * S1 + Pi_2.mean() * S2, 'r', lw=1.5, label='Static')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Comparison')
# Out:
# Text(0.5, 1.0, 'Comparison')

# %%
lr1 = np.log(BTC['Adj Close'] / BTC['Adj Close'].shift(1))
lr2 = np.log(ETH['Adj Close'] / ETH['Adj Close'].shift(1))
mu_1 = lr1.mean() * len(BTC)
mu_2 = lr2.mean() * len(BTC)
sigma_1 = lr1.std() * np.sqrt(len(BTC))
sigma_2 = lr2.std() * np.sqrt(len(ETH))
rho = lr1.corr(lr2)
z_0 = 0.00
gamma = 0.5
delta = 0.8
T = 1
M = len(BTC)

# %%
dt = T/M
S1 = np.zeros((M + 1, 1))
S2 = np.zeros((M + 1, 1))
z =  np.zeros((M + 1, 1))
a =  np.zeros((M + 1, 1))
b =  np.zeros((M + 1, 1))
c =  np.zeros((M + 1, 1))
Pi_1 = np.zeros((M + 1, 1))
Pi_2 = np.zeros((M + 1, 1))

# %%
tt = np.linspace(0, 1, M + 1)
z[0] = z_0
S1[0] = S1_0
S2[0] = S2_0
sigma_beta = np.sqrt(sigma_1 ** 2 + beta ** 2 * sigma_2 ** 2 + 2 * beta * sigma_1 * sigma_2 * rho)
eta = (-1/delta) * (mu_1 - sigma_1 ** 2/2 + beta*(mu_2 - sigma_2 ** 2/2))
rn = np.random.standard_normal(z.shape)
rn1 = np.random.standard_normal(S1.shape) 
rn2 = np.random.standard_normal(S2.shape) 
for t in range(1, M + 1):
    z[t] = z[t-1]* (1 - delta * (eta - z[t-1])) * dt + sigma_beta * np.sqrt(dt)*((sigma_1 + beta * sigma_2 * rho)/ sigma_beta * rn1[t] + beta * (sigma_2 * np.sqrt(1-rho ** 2)/sigma_beta) * rn1[t]);
    S1[t] = S1[t-1] * np.exp((mu_1 + delta * z[t] - sigma_1 ** 2 / 2) * dt + sigma_1 * np.sqrt(dt) * rn1[t])
    S2[t] = S2[t-1] * np.exp((mu_2 - sigma_2 ** 2 / 2) * dt + sigma_2 * np.sqrt(dt) * (rho * rn1[t] + np.sqrt(1 - rho ** 2) * rn2[t]))

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, S1, 'b', lw=1.5, label='Stock 1')
plt.plot(tt, S2, 'r', lw=1.5, label='Stock 2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Stock Price')
# Out:
# Text(0.5, 1.0, 'Stock Price')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, z, 'g', lw=1.5)
plt.xlabel('Time')
plt.ylabel('Rate')
plt.title('z')
# Out:
# Text(0.5, 1.0, 'z')

# %%
for t in range(1, M + 1):
    a[t] = 0.5 * (T - t * dt)/((1-rho ** 2) * sigma_1 ** 2)
    b[t] = - 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2)/((1 - rho ** 2) * sigma_1 ** 2) - rho * mu_2 * (T - t * dt)/((1 - rho **2) * sigma_1 * sigma_2)
    c[t] = 0.5 * mu_2 ** 2 * (T - t * dt)/((1 - rho ** 2) * sigma_2 ** 2) + 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2 + 2 * sigma_1 * sigma_2 * beta *rho) * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2) + 0.25 * (T - t * dt) ** 2 * mu_2 * delta * rho * (sigma_1 ** 2 + beta * sigma_2 ** 2) + 1/24 * (T - t * dt) ** 3 * (sigma_1 ** 2 + beta * sigma_2 ** 2) ** 2 * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2)
    Pi_1[t] = (1 / S1[t]) * ((mu_1 + delta * z[t])/(gamma * (1 - rho ** 2) * sigma_1 ** 2) + delta/gamma * (-2 * a[t] * (mu_1 + delta * z[t])-b[t]) - rho * mu_2/(gamma * (1 - rho ** 2) * sigma_1 * sigma_2))
    Pi_2[t] = (1 / S2[t]) * (mu_2 / (gamma * (1 - rho ** 2) * sigma_2 ** 2) + delta * beta / gamma * (- 2 * a[t] * (mu_1 + delta * z[t]) - b[t]) - rho)

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1, 'b', lw=1.5, label='w1')
plt.plot(tt, Pi_2, 'r', lw=1.5, label='w2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('%')
plt.title('Weights')
# Out:
# Text(0.5, 1.0, 'Weights')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1, 'b', lw=1.5, label='Wealth 1')
plt.plot(tt, Pi_2 * S2, 'r', lw=1.5, label='Wealth 2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Cash')
# Out:
# Text(0.5, 1.0, 'Cash')

# %%
Pi_1.mean()
# Out:
# -0.004452233088511883

# %%
Pi_2.mean()
# Out:
# 0.14090330182698352

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1 + Pi_2 * S2, 'b', lw=1.5, label='Dynamic')
plt.plot(tt, Pi_1.mean() * S1 + Pi_2.mean() * S2, 'r', lw=1.5, label='Static')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Comparison')
# Out:
# Text(0.5, 1.0, 'Comparison')

# %%
Wealth[1]
# Out:
# array([1253.82752657])

# %%
Wealth[-1]
# Out:
# array([555.56110219])

# %%
Return = (Wealth[-1] - Wealth[1])/Wealth[1]  # Return
Return.item()
# Out:
# -0.5569078757502648

# %%
rho
# Out:
# 0.8163628995515217
